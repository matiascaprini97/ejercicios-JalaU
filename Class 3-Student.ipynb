# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# Alex, Maria y Jonas son objetos de tipo Persona que tienen infinidad de atributos, Alex y tiene que proporcianar datos para registrarse en una clinica medica, encambio Maria cree en la esoteria y se esta registrando en una agencia esoterica pra tener un cita con la clarividente, Jonas por su lado se esta registrando en una red social, como pudes darte cuenta son 3 contextos diferentes.
# Se pide q modeles a los objetos (Alex, Maria y Jonas) en tres clases de acuerdo al contexto explicado en el enunciado, el resultado sera 3 clases y la diferencia seran los atributos q por medio de la abstraccion los definas.
#
# Puedes agregar un solo metodo q muestre en pantalla la informacion de cada uno de estos objetos (alex, maria, jonas)
#
# Tome como ejemplo la siguiente imagen explicado en clase, puede adicionar atributos si lo ves necesario
#
# ![image.png](data:image/png;base64,...)
#
# Debes tomar en cuenta las siguientes actividades:
#
# - clase Persona modelada respecto a la app de registro de una clinica medica
# - clase Persona modelada respecto a la app de registro de una centro esoterico
# - clase Persona modelada respecto a la app de registro de una red social
# - crear la instancias de los 3 objetos de tipo persona(Alex, Maria y Jonas)
# - mostrar la informacion de los objetos por medio del metodo mostrar informacion

# %%
# Aqui tu codigo

# %% [markdown]
# ### Ejercicio 2
#
# Tenemos la siguiete imagen donde se muestran los diferentes autos q dispone una tienda online, defina por medio de la abstraccion que atributos y q metodos deberia tener el objeto auto_juguete que sea relevante para crear la clase segun el contexto tienda online
#
# ![autos.png](data:image/png;base64,...)
#
# Actividades a tomar en cuenta:
#
# - Crear la clase con los atributos y metodos relevantes mediante la abstracion y el contexto de una tienda online
# - Hacer uso del contructor para crear las instancias de la clase AutoJuguete

# %%
# Aqui tu codigo

# %% [markdown]
# ### Ejercicio 3
# Modelar una Objeto Cuenta bancaria, para lo cual crear un clase con los siguietnes atributos: titular de la cuenta, saldo en su cuenta de banco, y el tipo de cuenta ademas del tipo de moneda de la cuenta (dolares o moneda nacional).
# los atributos como por ejemplo saldo sera de tipo decimal, y el tipo de cuenta es de tipo string, por lo cual el titular sera de tipo persona, para ello  necesitamos tambien modelar ese objeto (crear clase Persona con los atributos Nombre, Identificacion, Nacionalidad) por consiguiente titular sera de tipo Persona
#
# Actividades:
# - Crear la clase Cuenta de banco
# - Crear la clase Persona
# - Crear instancia de la clase persona haciendo uso del constructor
# - Crear instancia de la clase Cuenta haciendo uso del constructor, tenga en cuenta que el atributo titular es de tipo persona por lo que debe asignarsele la instancia creada del tipo persona.

# %%
# Aqui va tu codigo
