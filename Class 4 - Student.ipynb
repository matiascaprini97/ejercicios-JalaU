# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicios**

# %% [markdown]
# 1.- Escribe un programa que permita inscribir varios estudiantes a una materia. También incluye un método que permita ver qué alumnos fueron inscritos a dicha materia. No te olvides usar clases.

# %% [markdown]
# 2.- Escribe un programa muy básico similar a Netflix que permita agregar peliculas o series a una lista de favoritos. También incluye un método que permita ver cuáles películas o series están en la lista de favoritos. No te olvides de usar clases.

# %% [markdown]
# 3.- Dada una lista de números, escribe una función que, de manera declarativa, filtre solo los números pares y devuelva la lista resultante.

# %% [markdown]
# 4.- Dada una lista de números enteros, escribe una función que, de manera declarativa, convierta cada número a su representación textual en formato de palabras (por ejemplo, 5 a "cinco") y devuelva la lista resultante.

# %% [markdown]
# 5.-Se tiene una clase llamada ReproductorMusica que gestiona la reproducción de canciones, la creación de listas de reproducción y la generación de recomendaciones. Refactoriza la clase para respetar el principio de responsabilidad única.

# %%
class ReproductorMusica:
    def __init__(self):
        self.canciones = []
        self.listas_reproduccion = []

    def reproducir_cancion(self, cancion):
        # lógica para reproducir una canción

    def crear_lista_reproduccion(self, nombre_lista):
        # lógica para crear una lista de reproducción

    def generar_recomendaciones(self):
        # lógica para generar recomendaciones basadas en preferencias

# %% [markdown]
# 6.- Se tiene una clase llamada InventarioFerreteria que maneja la gestión de productos, la realización de pedidos y la generación de informes de ventas. Refactoriza la clase para respetar el principio de responsabilidad única.

# %%
class InventarioFerreteria:
    def __init__(self):
        self.productos = []
        self.pedidos = []

    def agregar_producto(self, producto):
        # lógica para agregar productos al inventario

    def realizar_pedido(self, producto, cantidad):
        # lógica para realizar un pedido de productos

    def generar_informe_ventas(self):
        # lógica para generar informes de ventas

# %% [markdown]
# 7.- Diseña un conjunto de clases para calcular el área y el perímetro de diferentes figuras geométricas como círculos, rectángulos y triángulos. Asegúrate de aplicar el principio DRY, evitando la repetición de código relacionado con el cálculo de áreas y perímetros.

# %% [markdown]
# 8.- Implementa un sistema básico para gestionar una lista de tareas pendientes (To Do List). Asegúrate de que la interfaz y las funciones del sistema sean simples y fáciles de entender. Evita agregar características complejas innecesarias y enfócate en la funcionalidad esencial.
